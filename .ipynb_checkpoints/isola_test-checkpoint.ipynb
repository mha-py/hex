# %%
# %load_ext autoreload
# %autoreload 2
from isola import *

# %%
s = GameState()
for _ in range(3000):
    print(f'Player {s.turn} moves:')
    m = GameIsola.getValidMoves(s)
    s = GameIsola.getNextState(s, np.random.choice(m))
    r = GameIsola.gameEnded(s)
    print_state(s)
    print()
    if r:
        print(f'Player {r} won!')
        break
# Out:
# Player 1 moves:
# ~ ~ ~ ~ ~ ~ ~ ~
# ~ r ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ ~ ~ ~ b
# ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ ~ ~ ~ ~
#
#
# Player -1 moves:
# ~ ~ ~ ~ ~ ~ ~ ~
# ~ r ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ . ~ ~ b
# ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ ~ ~ ~ ~
#
#
# Player -1 moves:
# ~ ~ ~ ~ ~ ~ ~ ~
# ~ r ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ . ~ ~ ~
# ~ ~ ~ ~ ~ ~ ~ b
# ~ ~ ~ ~ ~ ~ ~ ~
#
#
# Player 1 moves:
# ~ ~ ~ ~ ~ ~ ~ ~
# ~ r ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ . ~ ~ ~
# ~ ~ ~ ~ ~ . ~ b
# ~ ~ ~ ~ ~ ~ ~ ~
#
#
# Player 1 moves:
# ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ r ~ ~ ~ ~ ~
# ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ . ~ ~ ~
# ~ ~ ~ ~ ~ . ~ b
# ~ ~ ~ ~ ~ ~ ~ ~
#
#
# Player -1 moves:
# ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ r ~ ~ ~ ~ ~
# ~ ~ . ~ ~ ~ ~ ~
# ~ ~ ~ ~ . ~ ~ ~
# ~ ~ ~ ~ ~ . ~ b
# ~ ~ ~ ~ ~ ~ ~ ~
#
#
# Player -1 moves:
# ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ r ~ ~ ~ ~ ~
# ~ ~ . ~ ~ ~ ~ ~
# ~ ~ ~ ~ . ~ b ~
# ~ ~ ~ ~ ~ . ~ ~
# ~ ~ ~ ~ ~ ~ ~ ~
#
#
# Player 1 moves:
# ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ r ~ ~ ~ ~ ~
# ~ ~ . ~ ~ ~ ~ ~
# ...

# %%
r
# Out:
# -1

# %%
s.turn
# Out:
# 1

# %%
s.stage
# Out:
# 0
